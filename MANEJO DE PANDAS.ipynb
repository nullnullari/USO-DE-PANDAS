# %% [markdown]
# # Uso de PANDAS
# Pandas es una librería de Python esencial para la manipulación y análisis de datos. Es ampliamente utilizada por analistas y científicos de datos debido a su flexibilidad y potencia. Permite trabajar con estructuras de datos como DataFrames, facilitando la importación, manipulación y análisis de datos de diversas fuentes.
# Por lo que al saber esto en el siguiente ejercicio lo que se hará es algo similar a un EDA, quiere decir que hará un proceso de análisis de conjunto de datos para resumir características principales
#
#     Instrucciones:
#
#         - Generar un archivo tipo Notebook de Python que contenga el código fuente:
#
#         - Uso de librería Pandas para leer un archivo (fifa_eda.csv)
#
#         - Mostrar las primeras 20 filas del archivo, las últimas 5 y un sample de 10
#
#         - Generar data estadística con .describe() y además los tipos de datos del dataset
#
#         - Si es necesario, pasar a numéricas por lo menos 2 columnas que contengan números para incluirlas en .describe(). Aplicar las técnicas aprendidas.
#
#         - Añadir una columna “Years Playing”, que calcule el año actual menos la columna “Joined”
#
#         - Buscar y mostrar a todos los jugadores de Mexico
#
#         - Ordenar y mostrar los datos por la columna ReleaseClause (sueldo)
#
#         - Generar un nuevo dataset que contenga el año (joined) y el número de jugadores (groupby)

# %%
#Generacion de DataFrame con uso de PANDAS
import pandas as pd
fifa = pd.read_csv('fifa_eda.csv')
fifa
# Out:
#            ID                Name  Age Nationality  Overall  Potential  \
# 0      158023            L. Messi   31   Argentina       94         94
# 1       20801   Cristiano Ronaldo   33    Portugal       94         94
# 2      190871           Neymar Jr   26      Brazil       92         93
# 3      193080              De Gea   27       Spain       91         93
# 4      192985        K. De Bruyne   27     Belgium       91         92
# ...       ...                 ...  ...         ...      ...        ...
# 18202  238813        J. Lundstram   19     England       47         65
# 18203  243165  N. Christoffersson   19      Sweden       47         63
# 18204  241638           B. Worman   16     England       47         67
# 18205  246268      D. Walker-Rice   17     England       47         66
# 18206  246269           G. Nugent   16     England       46         66
#
#                       Club     Value   Wage Preferred Foot  \
# 0             FC Barcelona  110500.0  565.0           Left
# 1                 Juventus   77000.0  405.0          Right
# 2      Paris Saint-Germain  118500.0  290.0          Right
# 3        Manchester United   72000.0  260.0          Right
# 4          Manchester City  102000.0  355.0          Right
# ...                    ...       ...    ...            ...
# 18202      Crewe Alexandra      60.0    1.0          Right
# 18203       Trelleborgs FF      60.0    1.0          Right
# 18204     Cambridge United      60.0    1.0          Right
# 18205      Tranmere Rovers      60.0    1.0          Right
# 18206      Tranmere Rovers      60.0    1.0          Right
#
#        International Reputation  Skill Moves Position  Joined  \
# 0                           5.0          4.0       RF    2004
# 1                           5.0          5.0       ST    2018
# 2                           5.0          5.0       LW    2017
# 3                           4.0          1.0       GK    2011
# 4                           4.0          4.0      RCM    2015
# ...                         ...          ...      ...     ...
# 18202                       1.0          2.0       CM    2017
# 18203                       1.0          2.0       ST    2018
# 18204                       1.0          2.0       ST    2017
# 18205                       1.0          2.0       RW    2018
# 18206                       1.0          2.0       CM    2018
#
#       Contract Valid Until    Height  Weight  Release Clause
# 0               2021-01-01  5.583333   159.0        226500.0
# 1               2022-01-01  6.166667   183.0        127100.0
# 2               2022-01-01  5.750000   150.0        228100.0
# 3               2020-01-01  6.333333   168.0        138600.0
# 4               2023-01-01  5.916667   154.0        196400.0
# ...                    ...       ...     ...             ...
# 18202           2019-01-01  5.750000   134.0           143.0
# 18203           2020-01-01  6.250000   170.0           113.0
# 18204           2021-01-01  5.666667   148.0           165.0
# 18205           2019-01-01  5.833333   154.0           143.0
# 18206           2019-01-01  5.833333   176.0           165.0
#
# [18207 rows x 18 columns]

# %%
#Mostrar las primeras 20 filas del archivo
fifa.head(20)
# Out:
#         ID               Name  Age Nationality  Overall  Potential  \
# 0   158023           L. Messi   31   Argentina       94         94
# 1    20801  Cristiano Ronaldo   33    Portugal       94         94
# 2   190871          Neymar Jr   26      Brazil       92         93
# 3   193080             De Gea   27       Spain       91         93
# 4   192985       K. De Bruyne   27     Belgium       91         92
# 5   183277          E. Hazard   27     Belgium       91         91
# 6   177003          L. Modrić   32     Croatia       91         91
# 7   176580          L. Suárez   31     Uruguay       91         91
# 8   155862       Sergio Ramos   32       Spain       91         91
# 9   200389           J. Oblak   25    Slovenia       90         93
# 10  188545     R. Lewandowski   29      Poland       90         90
# 11  182521           T. Kroos   28     Germany       90         90
# 12  182493           D. Godín   32     Uruguay       90         90
# 13  168542        David Silva   32       Spain       90         90
# 14  215914           N. Kanté   27      France       89         90
# 15  211110          P. Dybala   24   Argentina       89         94
# 16  202126            H. Kane   24     England       89         91
# 17  194765       A. Griezmann   27      France       89         90
# 18  192448      M. ter Stegen   26     Germany       89         92
# 19  192119        T. Courtois   26     Belgium       89         90
#
#                    Club     Value   Wage Preferred Foot  \
# 0          FC Barcelona  110500.0  565.0           Left
# 1              Juventus   77000.0  405.0          Right
# 2   Paris Saint-Germain  118500.0  290.0          Right
# 3     Manchester United   72000.0  260.0          Right
# 4       Manchester City  102000.0  355.0          Right
# 5               Chelsea   93000.0  340.0          Right
# 6           Real Madrid   67000.0  420.0          Right
# 7          FC Barcelona   80000.0  455.0          Right
# 8           Real Madrid   51000.0  380.0          Right
# 9       Atlético Madrid   68000.0   94.0          Right
# 10    FC Bayern München   77000.0  205.0          Right
# 11          Real Madrid   76500.0  355.0          Right
# 12      Atlético Madrid   44000.0  125.0          Right
# 13      Manchester City   60000.0  285.0           Left
# 14              Chelsea   63000.0  225.0          Right
# 15             Juventus   89000.0  205.0           Left
# 16    Tottenham Hotspur   83500.0  205.0          Right
# 17      Atlético Madrid   78000.0  145.0           Left
# 18         FC Barcelona   58000.0  240.0          Right
# 19          Real Madrid   53500.0  240.0           Left
#
#     International Reputation  Skill Moves Position  Joined  \
# 0                        5.0          4.0       RF    2004
# 1                        5.0          5.0       ST    2018
# 2                        5.0          5.0       LW    2017
# 3                        4.0          1.0       GK    2011
# 4                        4.0          4.0      RCM    2015
# 5                        4.0          4.0       LF    2012
# 6                        4.0          4.0      RCM    2012
# 7                        5.0          3.0       RS    2014
# 8                        4.0          3.0      RCB    2005
# 9                        3.0          1.0       GK    2014
# 10                       4.0          4.0       ST    2014
# 11                       4.0          3.0      LCM    2014
# 12                       3.0          2.0       CB    2010
# 13                       4.0          4.0      LCM    2010
# 14                       3.0          2.0      LDM    2016
# 15                       3.0          4.0       LF    2015
# 16                       3.0          3.0       ST    2010
# 17                       4.0          4.0      CAM    2014
# 18                       3.0          1.0       GK    2014
# 19                       4.0          1.0       GK    2018
#
#    Contract Valid Until    Height  Weight  Release Clause
# 0            2021-01-01  5.583333   159.0        226500.0
# 1            2022-01-01  6.166667   183.0        127100.0
# 2            2022-01-01  5.750000   150.0        228100.0
# 3            2020-01-01  6.333333   168.0        138600.0
# 4            2023-01-01  5.916667   154.0        196400.0
# 5            2020-01-01  5.666667   163.0        172100.0
# 6            2020-01-01  5.666667   146.0        137400.0
# 7            2021-01-01  6.000000   190.0        164000.0
# 8            2020-01-01  6.000000   181.0        104600.0
# 9            2021-01-01  6.166667   192.0        144500.0
# 10           2021-01-01  6.000000   176.0        127100.0
# 11           2022-01-01  6.000000   168.0        156800.0
# 12           2019-01-01  6.166667   172.0         90200.0
# 13           2020-01-01  5.666667   148.0        111000.0
# 14           2023-01-01  5.500000   159.0        121300.0
# 15           2022-01-01  5.833333   165.0        153500.0
# 16           2024-01-01  6.166667   196.0        160700.0
# 17           2023-01-01  5.750000   161.0        165800.0
# 18           2022-01-01  6.166667   187.0        123300.0
# 19           2024-01-01  6.500000   212.0        113700.0

# %%
#Mostrar las ultimas 5 filas
fifa.tail()
# Out:
#            ID                Name  Age Nationality  Overall  Potential  \
# 18202  238813        J. Lundstram   19     England       47         65
# 18203  243165  N. Christoffersson   19      Sweden       47         63
# 18204  241638           B. Worman   16     England       47         67
# 18205  246268      D. Walker-Rice   17     England       47         66
# 18206  246269           G. Nugent   16     England       46         66
#
#                    Club  Value  Wage Preferred Foot  International Reputation  \
# 18202   Crewe Alexandra   60.0   1.0          Right                       1.0
# 18203    Trelleborgs FF   60.0   1.0          Right                       1.0
# 18204  Cambridge United   60.0   1.0          Right                       1.0
# 18205   Tranmere Rovers   60.0   1.0          Right                       1.0
# 18206   Tranmere Rovers   60.0   1.0          Right                       1.0
#
#        Skill Moves Position  Joined Contract Valid Until    Height  Weight  \
# 18202          2.0       CM    2017           2019-01-01  5.750000   134.0
# 18203          2.0       ST    2018           2020-01-01  6.250000   170.0
# 18204          2.0       ST    2017           2021-01-01  5.666667   148.0
# 18205          2.0       RW    2018           2019-01-01  5.833333   154.0
# 18206          2.0       CM    2018           2019-01-01  5.833333   176.0
#
#        Release Clause
# 18202           143.0
# 18203           113.0
# 18204           165.0
# 18205           143.0
# 18206           165.0

# %%
#Mostrar 20 samples
fifa.sample(20)
# Out:
#            ID           Name  Age     Nationality  Overall  Potential  \
# 13275  244541    E. González   23       Venezuela       62         70
# 10641  213171    Ka Sol Heon   27  Korea Republic       65         65
# 709    164029        Charles   34          Brazil       79         79
# 1045   143745       A. Turan   31          Turkey       77         77
# 6956   162900    N. Kilkenny   32       Australia       68         68
# 11780  210368      J. Duncan   25       Australia       64         67
# 2658   203544        C. Löwe   29         Germany       73         73
# 14941  244081       N. Plume   21         Germany       60         69
# 15983  245846    Y. Oyanedel   17           Chile       58         78
# 15094  236209        D. Hume   21         England       60         70
# 17286  236551     H. Darling   18         England       54         68
# 10316  238941    J. Balkovec   23        Slovenia       65         71
# 17280  229375     E. Adebayo   20         England       55         67
# 3420   149571  S. Pellissier   39           Italy       72         72
# 5767   215332      C. Auzqui   27       Argentina       69         69
# 12126  235022     N. Schmidt   20         Germany       63         76
# 15042  176793       R. Lawan   30          Sweden       60         60
# 16486  243593   A. Laurienté   19          France       57         69
# 1765   213597      D. Valdés   24           Chile       75         79
# 17588  244311  Lucas Ribeiro   19          Brazil       53         71
#
#                              Club   Value   Wage Preferred Foot  \
# 13275             Boyacá Chicó FC   375.0    1.0          Right
# 10641             Jeonnam Dragons   450.0    2.0          Right
# 709                      SD Eibar  6500.0   31.0          Right
# 1045        Medipol Başakşehir FK  7500.0  120.0          Right
# 6956                  Perth Glory   525.0    3.0          Right
# 11780                Al Qadisiyah   400.0    3.0          Right
# 2658            Huddersfield Town  3000.0   34.0           Left
# 14941      VfL Sportfreunde Lotte   280.0    1.0          Right
# 15983        Universidad Católica   220.0    1.0           Left
# 15094                  Sunderland   290.0    1.0           Left
# 17286            Cambridge United   130.0    1.0          Right
# 10316               Hellas Verona   625.0    1.0           Left
# 17280                Swindon Town   160.0    6.0          Right
# 3420                Chievo Verona   900.0   10.0          Right
# 5767        Club Atlético Huracán  1100.0   11.0          Right
# 12126          SV Wehen Wiesbaden   700.0    4.0          Right
# 15042                  Dalkurd FF   190.0    1.0          Right
# 16486  US Orléans Loiret Football   180.0    2.0          Right
# 1765             Monarcas Morelia  8500.0   10.0          Right
# 17588             Valenciennes FC   130.0    1.0           Left
#
#        International Reputation  Skill Moves Position  Joined  \
# 13275                       NaN          NaN       LB    2016
# 10641                       1.0          2.0       CB    2018
# 709                         1.0          4.0       LS    2017
# 1045                        3.0          4.0       CM    2016
# 6956                        1.0          2.0      LDM    2018
# 11780                       1.0          1.0       GK    2018
# 2658                        1.0          3.0      LWB    2016
# 14941                       1.0          2.0      CDM    2018
# 15983                       1.0          2.0       LB    2017
# 15094                       1.0          2.0       LB    2016
# 17286                       1.0          2.0       CB    2016
# 10316                       1.0          2.0       LB    2018
# 17280                       1.0          2.0       LW    2016
# 3420                        2.0          3.0       ST    2002
# 5767                        1.0          3.0       RM    2016
# 12126                       1.0          3.0      CAM    2016
# 15042                       1.0          2.0       CM    2016
# 16486                       1.0          3.0      CAM    2016
# 1765                        1.0          4.0      CAM    2016
# 17588                       1.0          2.0       LM    2018
#
#       Contract Valid Until    Height      Weight  Release Clause
# 13275                  NaN  5.946771  165.979129     4585.060806
# 10641           2023-01-01  6.333333  190.000000      563.000000
# 709             2019-01-01  5.833333  165.000000    13700.000000
# 1045            2020-05-31  5.833333  168.000000     4585.060806
# 6956            2021-01-01  5.666667  148.000000      656.000000
# 11780           2019-01-01  6.166667  181.000000      690.000000
# 2658            2019-01-01  5.750000  150.000000     5700.000000
# 14941           2020-01-01  6.166667  172.000000      462.000000
# 15983           2019-01-01  5.583333  146.000000      528.000000
# 15094           2019-01-01  5.666667  132.000000      566.000000
# 17286           2021-01-01  5.916667  165.000000      309.000000
# 10316           2021-01-01  6.083333  176.000000     1100.000000
# 17280           2019-06-30  6.333333  196.000000     4585.060806
# 3420            2019-01-01  5.750000  168.000000     1500.000000
# 5767            2019-06-30  5.916667  163.000000     4585.060806
# 12126           2019-06-30  6.000000  198.000000     4585.060806
# 15042           2018-01-01  5.833333  172.000000      238.000000
# 16486           2019-06-30  5.583333  130.000000     4585.060806
# 1765            2023-01-01  5.833333  165.000000    15100.000000
# 17588           2019-01-01  5.666667  132.000000      309.000000

# %%
#Generar inforamcion estadistica con .describe()
fifa.describe().T
# Out:
#                             count           mean           std      min  \
# ID                        18207.0  214298.338606  29965.244204    16.00
# Age                       18207.0      25.122206      4.669943    16.00
# Overall                   18207.0      66.238699      6.908930    46.00
# Potential                 18207.0      71.307299      6.136496    48.00
# Value                     18207.0    2410.695886   5594.932671     0.00
# Wage                      18207.0       9.731312     21.999290     0.00
# International Reputation  18207.0       1.110287      0.397630     0.00
# Skill Moves               18207.0       2.355083      0.764813     0.00
# Joined                    18207.0    2016.420607      2.018194  1991.00
# Height                    18207.0       5.946675      0.220715     5.08
# Weight                    18207.0     165.976547     15.572856   110.00
# Release Clause            18207.0    4585.055693  10630.414118    13.00
# Years Playing             18207.0       9.579393      2.018194     8.00
#
#                                 25%        50%        75%        max
# ID                        200315.50  221759.00  236529.50  246620.00
# Age                           21.00      25.00      28.00      45.00
# Overall                       62.00      66.00      71.00      94.00
# Potential                     67.00      71.00      75.00      95.00
# Value                        300.00     675.00    2000.00  118500.00
# Wage                           1.00       3.00       9.00     565.00
# International Reputation       1.00       1.00       1.00       5.00
# Skill Moves                    2.00       2.00       3.00       5.00
# Joined                      2016.00    2017.00    2018.00    2018.00
# Height                         5.75       5.92       6.08       6.75
# Weight                       154.00     165.00     176.00     243.00
# Release Clause               570.00    1300.00    4585.00  228100.00
# Years Playing                  8.00       9.00      10.00      35.00

# %%
#Reconocer si hay valores repetidos o nulos del DataFrame
fifa.isnull().sum()
# Out:
# ID                            0
# Name                          0
# Age                           0
# Nationality                   0
# Overall                       0
# Potential                     0
# Club                        241
# Value                       252
# Wage                          0
# Preferred Foot                0
# International Reputation     48
# Skill Moves                  48
# Position                      0
# Joined                        0
# Contract Valid Until        289
# Height                        0
# Weight                        0
# Release Clause                0
# dtype: int64

# %%
#Rellnar los espacios NaN con cero del Data Frame para su transformación
fifa = fifa.fillna(0)

# %%
#Verificar si el DF esta limpio
fifa.isnull().sum()
# Out:
# ID                          0
# Name                        0
# Age                         0
# Nationality                 0
# Overall                     0
# Potential                   0
# Club                        0
# Value                       0
# Wage                        0
# Preferred Foot              0
# International Reputation    0
# Skill Moves                 0
# Position                    0
# Joined                      0
# Contract Valid Until        0
# Height                      0
# Weight                      0
# Release Clause              0
# dtype: int64

# %%
#Transforamcion de tipo de dato a int
fifa = fifa.astype({
    'Value':int,
    'Wage':int,
    'International Reputation': int,
    'Skill Moves':int,
    'Weight':int,
    'Release Clause': int
})
fifa['Height'] = fifa['Height'].round(2)

# %%
#Verificacion de la transformacion que se realizo en el DF
fifa
# Out:
#            ID                Name  Age Nationality  Overall  Potential  \
# 0      158023            L. Messi   31   Argentina       94         94
# 1       20801   Cristiano Ronaldo   33    Portugal       94         94
# 2      190871           Neymar Jr   26      Brazil       92         93
# 3      193080              De Gea   27       Spain       91         93
# 4      192985        K. De Bruyne   27     Belgium       91         92
# ...       ...                 ...  ...         ...      ...        ...
# 18202  238813        J. Lundstram   19     England       47         65
# 18203  243165  N. Christoffersson   19      Sweden       47         63
# 18204  241638           B. Worman   16     England       47         67
# 18205  246268      D. Walker-Rice   17     England       47         66
# 18206  246269           G. Nugent   16     England       46         66
#
#                       Club   Value  Wage Preferred Foot  \
# 0             FC Barcelona  110500   565           Left
# 1                 Juventus   77000   405          Right
# 2      Paris Saint-Germain  118500   290          Right
# 3        Manchester United   72000   260          Right
# 4          Manchester City  102000   355          Right
# ...                    ...     ...   ...            ...
# 18202      Crewe Alexandra      60     1          Right
# 18203       Trelleborgs FF      60     1          Right
# 18204     Cambridge United      60     1          Right
# 18205      Tranmere Rovers      60     1          Right
# 18206      Tranmere Rovers      60     1          Right
#
#        International Reputation  Skill Moves Position  Joined  \
# 0                             5            4       RF    2004
# 1                             5            5       ST    2018
# 2                             5            5       LW    2017
# 3                             4            1       GK    2011
# 4                             4            4      RCM    2015
# ...                         ...          ...      ...     ...
# 18202                         1            2       CM    2017
# 18203                         1            2       ST    2018
# 18204                         1            2       ST    2017
# 18205                         1            2       RW    2018
# 18206                         1            2       CM    2018
#
#       Contract Valid Until  Height  Weight  Release Clause
# 0               2021-01-01    5.58     159          226500
# 1               2022-01-01    6.17     183          127100
# 2               2022-01-01    5.75     150          228100
# 3               2020-01-01    6.33     168          138600
# 4               2023-01-01    5.92     154          196400
# ...                    ...     ...     ...             ...
# 18202           2019-01-01    5.75     134             143
# 18203           2020-01-01    6.25     170             113
# 18204           2021-01-01    5.67     148             165
# 18205           2019-01-01    5.83     154             143
# 18206           2019-01-01    5.83     176             165
#
# [18207 rows x 18 columns]

# %%
#Verificacion .decribe()
fifa.describe().T
# Out:
#                             count           mean           std      min  \
# ID                        18207.0  214298.338606  29965.244204    16.00
# Age                       18207.0      25.122206      4.669943    16.00
# Overall                   18207.0      66.238699      6.908930    46.00
# Potential                 18207.0      71.307299      6.136496    48.00
# Value                     18207.0    2410.695886   5594.932671     0.00
# Wage                      18207.0       9.731312     21.999290     0.00
# International Reputation  18207.0       1.110287      0.397630     0.00
# Skill Moves               18207.0       2.355083      0.764813     0.00
# Joined                    18207.0    2016.420607      2.018194  1991.00
# Height                    18207.0       5.946675      0.220715     5.08
# Weight                    18207.0     165.976547     15.572856   110.00
# Release Clause            18207.0    4585.055693  10630.414118    13.00
# Years Playing             18207.0       9.579393      2.018194     8.00
#
#                                 25%        50%        75%        max
# ID                        200315.50  221759.00  236529.50  246620.00
# Age                           21.00      25.00      28.00      45.00
# Overall                       62.00      66.00      71.00      94.00
# Potential                     67.00      71.00      75.00      95.00
# Value                        300.00     675.00    2000.00  118500.00
# Wage                           1.00       3.00       9.00     565.00
# International Reputation       1.00       1.00       1.00       5.00
# Skill Moves                    2.00       2.00       3.00       5.00
# Joined                      2016.00    2017.00    2018.00    2018.00
# Height                         5.75       5.92       6.08       6.75
# Weight                       154.00     165.00     176.00     243.00
# Release Clause               570.00    1300.00    4585.00  228100.00
# Years Playing                  8.00       9.00      10.00      35.00

# %%
#Añadir columna de "Years Playing" 
#Que calcule el año actual menos la columna "Joined"
fifa['Years Playing'] =  2026 - fifa['Joined']
fifa
# Out:
#            ID                Name  Age Nationality  Overall  Potential  \
# 0      158023            L. Messi   31   Argentina       94         94
# 1       20801   Cristiano Ronaldo   33    Portugal       94         94
# 2      190871           Neymar Jr   26      Brazil       92         93
# 3      193080              De Gea   27       Spain       91         93
# 4      192985        K. De Bruyne   27     Belgium       91         92
# ...       ...                 ...  ...         ...      ...        ...
# 18202  238813        J. Lundstram   19     England       47         65
# 18203  243165  N. Christoffersson   19      Sweden       47         63
# 18204  241638           B. Worman   16     England       47         67
# 18205  246268      D. Walker-Rice   17     England       47         66
# 18206  246269           G. Nugent   16     England       46         66
#
#                       Club   Value  Wage Preferred Foot  \
# 0             FC Barcelona  110500   565           Left
# 1                 Juventus   77000   405          Right
# 2      Paris Saint-Germain  118500   290          Right
# 3        Manchester United   72000   260          Right
# 4          Manchester City  102000   355          Right
# ...                    ...     ...   ...            ...
# 18202      Crewe Alexandra      60     1          Right
# 18203       Trelleborgs FF      60     1          Right
# 18204     Cambridge United      60     1          Right
# 18205      Tranmere Rovers      60     1          Right
# 18206      Tranmere Rovers      60     1          Right
#
#        International Reputation  Skill Moves Position  Joined  \
# 0                             5            4       RF    2004
# 1                             5            5       ST    2018
# 2                             5            5       LW    2017
# 3                             4            1       GK    2011
# 4                             4            4      RCM    2015
# ...                         ...          ...      ...     ...
# 18202                         1            2       CM    2017
# 18203                         1            2       ST    2018
# 18204                         1            2       ST    2017
# 18205                         1            2       RW    2018
# 18206                         1            2       CM    2018
#
#       Contract Valid Until  Height  Weight  Release Clause  Years Playing
# 0               2021-01-01    5.58     159          226500             22
# 1               2022-01-01    6.17     183          127100              8
# 2               2022-01-01    5.75     150          228100              9
# 3               2020-01-01    6.33     168          138600             15
# 4               2023-01-01    5.92     154          196400             11
# ...                    ...     ...     ...             ...            ...
# 18202           2019-01-01    5.75     134             143              9
# 18203           2020-01-01    6.25     170             113              8
# 18204           2021-01-01    5.67     148             165              9
# 18205           2019-01-01    5.83     154             143              8
# 18206           2019-01-01    5.83     176             165              8
#
# [18207 rows x 19 columns]

# %%
#Mostrar todos los jugadores de Mexico
fifa[['Name','Age','Nationality','Club','Contract Valid Until','Joined','Height','Years Playing']].loc[fifa['Nationality'] == 'Mexico'].sort_values(by = 'Joined')
# Out:
#                Name  Age Nationality                         Club  \
# 4741       O. Pérez   45      Mexico                      Pachuca
# 5187   J. Domínguez   30      Mexico                    Cruz Azul
# 3614      L. Montes   32      Mexico                    Club León
# 4837     D. Cabrera   28      Mexico                     U.N.A.M.
# 5992     I. Jiménez   28      Mexico              Tigres U.A.N.L.
# ...             ...  ...         ...                          ...
# 17310   E. Pastrana   18      Mexico  Tiburones Rojos de Veracruz
# 17228   J. Alvarado   18      Mexico                    Monterrey
# 16118      J. Veyna   23      Mexico                  Club Necaxa
# 18037      C. Landa   19      Mexico  Tiburones Rojos de Veracruz
# 17373  R. Gutiérrez   22      Mexico             Monarcas Morelia
#
#       Contract Valid Until  Joined  Height  Years Playing
# 4741            2021-01-01    1991    5.67             35
# 5187            2021-01-01    2006    5.75             20
# 3614            2021-01-01    2007    5.42             19
# 4837            2021-01-01    2008    5.92             18
# 5992            2021-01-01    2008    5.75             18
# ...                    ...     ...     ...            ...
# 17310           2021-01-01    2018    5.75              8
# 17228           2021-01-01    2018    5.42              8
# 16118           2021-01-01    2018    5.92              8
# 18037           2021-01-01    2018    6.00              8
# 17373           2021-01-01    2018    5.92              8
#
# [366 rows x 8 columns]

# %%
# Orden por la columna ReleaseClause(Sueldo)
fifa[['Name','Age','Nationality','Club','Release Clause']].loc[fifa['Release Clause'] >13 ].sort_values(by='Release Clause', ascending = False)
# Out:
#                   Name  Age   Nationality                 Club  Release Clause
# 2            Neymar Jr   26        Brazil  Paris Saint-Germain          228100
# 0             L. Messi   31     Argentina         FC Barcelona          226500
# 4         K. De Bruyne   27       Belgium      Manchester City          196400
# 5            E. Hazard   27       Belgium              Chelsea          172100
# 25           K. Mbappé   19        France  Paris Saint-Germain          166100
# ...                ...  ...           ...                  ...             ...
# 17657       J. McCombe   35       England         Lincoln City              18
# 16596     A. Al Basisi   40  Saudi Arabia            Ohod Club              17
# 15133        M. Gurski   39       Germany   SpVgg Unterhaching              15
# 16264  P. van der Vlag   40   Netherlands             FC Emmen              15
# 17704      F. Nicastro   36         Italy      Neuchâtel Xamax              15
#
# [18202 rows x 5 columns]

# %%
#Generar un nuevo dataset que contenga el año (joined) y el numero de jugadores(groupby)
fifa_temp = fifa.groupby('Joined').count()[ 'Nationality'].sort_values(ascending = False)[0:10]

# %%
#Generar un gráfico que contenga el número de jugadores y el año

import matplotlib.pyplot as plt
ax = fifa_temp.plot.bar(x = 'Nationality',y= 'Joined',rot = 20,color = 'darkgreen' )
ax.set_title('Numero de jugadores que se unieron')
ax.set_xlabel('Años')
ax.set_ylabel('No.Jugadores')
ax.legend('Años')
plt.show()
